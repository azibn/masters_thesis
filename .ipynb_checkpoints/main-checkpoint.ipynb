# %% [markdown]
# # MSc Project Notebook

# %% [markdown]
# Steps of obtaining raw spectra and converting into radial velocities:
# - CCD cameras record the spectral data as flux (magnitude) and wavelength
#
#
# - Simulate a binary model using [SB9 Catalogue](https://heasarc.gsfc.nasa.gov/W3Browse/all/sborbitcat.html) adn fit with spectral data.
# - Gaia observes a source on average 40 times, so a randomly generated array of 40 values (to replicate the 40 unique observations) is applied to the binary model.
# - Gaussian filter applied, and resample the spectra to 0.025nm from 0.001nm (RVS spectra resolution is 0.025nm and we want to replicate this).
# - Normalise the spectra. This is now our template spectra.
# - Doppler shift each of the now normalised spectra by each of the values of the 40 observations. We now get 40 different spectra.
# - Cross correlate these new spectra with the template spectra and therefore obtain 40 cross correlation functions.
#
# - We want to then shift the new CCF's to rest. Since we know the rest template, there is a shortcut but this idea would need to be developed for the real data cases (I think).

# %% [markdown]
# ### Importing packages:

# %%
from __future__ import print_function, division
from PyAstronomy import pyasl
import numpy as np
import statistics
import matplotlib.pylab as plt
import pandas as pd
from astropy.convolution import convolve
import scipy
import math
import spectres
np.warnings.filterwarnings('ignore') 
# %run -i 'Cross Correlation Function.py'
# %matplotlib inline
SEED = 42

# %% [markdown]
# Reading in the data:

# %%
data = pd.read_csv("xx03",delim_whitespace=True).rename(columns= {"sourceId": "wavelength", "57500450000": "flux"})

# %% [markdown]
# Resolution of dataset is 0.001nm. In comparison, RVS resolution is 0.025nm. Sanity check of data:

# %%
data.plot(style='.',x='wavelength',y='flux',ms=0.8, figsize=(10,5))
_ = plt.show()

# %% [markdown]
# Single Star (can only see brighter star) - shifting wrt RV implies secondary (implied SB1 as we don't see both spectral data clearly, unlike SB2)
#
# In principle can apply this with SB2 but becomes more complicated as two templates will be moving as opposed to one, therefore simultaneous methods

# %% [markdown]
# Defining parameters:

# %%
sig_rvs = (860.5/11500.)/2.35482

# %% [markdown]
# ---

# %% [markdown]
# ### IDL to Python conversion (file: normspec.pro)

# %%
def norm_flux_array(data=data):
    flux_size = data.flux.size
    x1 = 25
    x2 = flux_size-1-25
    y1 = np.median(data.flux[0:51]) # first 50 data points
    y2 = np.median(data.flux[-51:-1]) # last 50 data points
    gradient = (y2-y1)/(x2-x1)
    first_flux_point = data.flux[0]

    linear_flux = np.zeros((flux_size),float)
    for i in range(0,flux_size-1):
        linear_flux[i] = first_flux_point + (gradient*i)
    norm_flux_array = data.flux/linear_flux  
    plt.figure(figsize=(10,5))
    plt.scatter(data.wavelength, norm_flux_array, s=1)
    plt.show()
    
norm_flux_array()

# %% [markdown]
# Normalising dataset:

# %% [markdown]
# Continuum normalisation. Approximating to original data.
# - Trying to compare absorption lines relative to template.
# - If continuum is more sloped in parts than other, parts not always treated equally.

# %% [markdown]
# ## Radial Velocity equation for Gaia's nominal mission duration:

# %%
def binary_model(gamma,K,P,tau):
    RV = []
    for t in np.arange(0,1825):
        v = (2*math.pi)*(t-tau)/P
        RV.append(gamma + K*np.cos(v))
    plt.figure(figsize=(20,2))
    plt.plot(RV)
    plt.xlabel('Period in Days', fontsize=14)
    plt.ylabel('Radial Velocity in km/s', fontsize=14)
    return RV
    #plt.show()
    # From SB9 catalogue. In real world, I wouldnt know this first hand

# %% [markdown]
# ## Radial Velocity for 40 random observations:

# %%
 # Seeding the randomness
np.random.seed(SEED)
rand = np.random.randint(0,1825,40)

# %%
def Gaia_transits(gamma,K,P,tau):
    RV = []

    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV.append(gamma + K*np.cos(v))
#     plt.figure(figsize=(20,2))
#     plt.plot(rand,RV,'s')
#     plt.xlabel('time in days', fontsize=14)
#     plt.ylabel('Radial Velocity in km/s', fontsize=14)
    return RV

Gaia_transit = Gaia_transits(0,20,40,0)

# %%
def complete_binary_plot():

    plt.figure(figsize=(20,2))
    plt.plot(binary_model)
    plt.plot(rand,Gaia_transits,'s')
    plt.xlabel('time in days', fontsize=14)
    plt.ylabel('Radial Velocity in km/s', fontsize=14)
    plt.title('Binary model with the 40 random Gaia transits',fontsize=16)
    plt.show()
complete_binary_plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Documents/MSc/MSc_Thesis/Cross Correlation Function.py in <module>
#       8     plt.title('Binary model with the 40 random Gaia transits',fontsize=16)
#       9     plt.show()
# ---> 10 complete_binary_plot()
#
# ~/Documents/MSc/MSc_Thesis/Cross Correlation Function.py in complete_binary_plot()
#       2
#       3     plt.figure(figsize=(20,2))
# ----> 4     plt.plot(binary_model)
#       5     plt.plot(rand,Gaia_transits,'s')
#       6     plt.xlabel('time in days', fontsize=14)
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# -> 1607             self.add_line(line)
#    1608         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609         return lines
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    2099             line.set_clip_path(self.patch)
#    2100
# -> 2101         self._update_line_limits(line)
#    2102         if not line.get_label():
#    2103             line.set_label('_line%d' % len(self.lines))
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    2121         Figures out the data limit of the given line, updating self.dataLim.
#    2122         """
# -> 2123         path = line.get_path()
#    2124         if path.vertices.size == 0:
#    2125             return
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/lines.py in recache(self, always)
#     666         if always or self._invalidy:
#     667             yconv = self.convert_yunits(self._yorig)
# --> 668             y = _to_unmasked_float_array(yconv).ravel()
#     669         else:
#     670             y = self._y
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1331         return np.ma.asarray(x, float).filled(np.nan)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#    1335
#
# ~/opt/anaconda3/envs/polychordv2/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'function'

# %% [markdown]
# Approximating that Gaia scan law.

# %% [markdown]
# ---

# %% [markdown]
# #### Convolving flux with a Gaussian Line Spread Function

# %%
convolved_flux = scipy.ndimage.gaussian_filter1d(data.flux,sig_rvs)

# %% [markdown]
# revised parameters

# %% [markdown]
# resample here:

# %% [markdown]
# inherent from photon electron capture

# %% [markdown]
# gaussian noise is uncertainty just from reading from a detector.

# %%
#b = noise[0]
#y1_norm = np.median(noise[0:51])
#y2_norm = np.median(noise[-51:-1])
#linear_flux2 = np.zeros((n),float)
#grad_norm = (y2_norm-y1_norm)/(x2-x1)
#for i in range(0,n-1):
#    linear_flux2[i] = b + (grad_norm*i)

# %%
wavelength = data.wavelength.to_numpy()
wavelength
# Out:
# array([840.   , 840.001, 840.002, ..., 889.998, 889.999, 890.   ])

# %%
rvs_wavelength = np.arange(840,890,0.025)
rvs_flux = spectres.spectres(rvs_wavelength,wavelength,convolved_flux)
rvs_flux = np.nan_to_num(rvs_flux, nan=47619.2)
# Out:
# Spectres: new_wavs contains values outside the range in spec_wavs, new_fluxes and new_errs will be filled with the value set in the 'fill' keyword argument.

# %% [markdown]
# Resampling new template:

# %%
rvs_flux_size = rvs_flux.size
x1_rvs = 25
x2_rvs = rvs_flux_size-1-25
y1_rvs = np.median(rvs_flux[0:51])
y2_rvs = np.median(rvs_flux[-51:-1])
rvs_first_flux_point = rvs_flux[0]
gradient_rvs = (y2_rvs-y1_rvs)/(x2_rvs-x1_rvs)
linear_flux_rvs = np.zeros((rvs_flux_size),float)
for i in range(0,rvs_flux_size-1):
    linear_flux_rvs[i] = rvs_first_flux_point + (gradient_rvs)*i
    """Normalising the convolved flux"""
norm_flux_array_rvs = rvs_flux/linear_flux_rvs
plt.figure(figsize=(20,5))
plt.plot(rvs_wavelength,norm_flux_array_rvs,'b')
plt.show()

# %% [markdown]
# RVS wavelength range: 846-870nm:

# %% [markdown]
# Doppler Shifting the full spectra wrt the 40 RV's calculated earlier:

# %%
flux = []
wlprime = []
for i in range(40):
    flux.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,Gaia_transit[i])[0])
    wlprime.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,Gaia_transit[i])[1])

# %% [markdown]
# Slicing these shifted spectra to fit the RVS wavelength range:

# %%
# %%time
nflux_rvs = []
wlprime_rvs = []

for i in range(40):
    nflux_rvs.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,Gaia_transit[i])[0][240:1200])
    wlprime_rvs.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,Gaia_transit[i])[1][240:1200])
# Out:
# CPU times: user 17.7 ms, sys: 2.23 ms, total: 19.9 ms
# Wall time: 18.4 ms

# %% [markdown]
# ---

# %% [markdown]
# #### Cross Correlating

# %% [markdown]
# Cross correlating the template at rest to double check:

# %%
rv_test, cc_test = crosscorrRV(
    rvs_wavelength[240:1200],norm_flux_array_rvs[240:1200],
    rvs_wavelength,norm_flux_array_rvs,-1000.,1000.,1.,mode='doppler',skipedge=0)

# %% [markdown]
# Cross correlating our shifted spectra with respect to the template

# %%
# %%time
rv = []
cc = []

for i in range(40):
    rv.append(crosscorrRV(wlprime_rvs[i],nflux_rvs[i],rvs_wavelength,norm_flux_array_rvs,-1000.,1000.,1.,mode='doppler',skipedge=0)[0])
    cc.append(crosscorrRV(wlprime_rvs[i],nflux_rvs[i],rvs_wavelength,norm_flux_array_rvs,-1000.,1000.,1.,mode='doppler',skipedge=0)[1])
# Out:
# CPU times: user 24.1 s, sys: 80.1 ms, total: 24.2 s
# Wall time: 24.2 s

# %%
plt.figure(figsize=(15,10))
maxind_tem = np.argmax(cc_test)
#print("Template cross-correlation function is maximized at RV = ", rv_tem[maxind_tem], " km/s")
maxind = [np.argmax(cc[i]) for i in range(40)]

plt.plot(rv_test,cc_test,'k')
for i in range(40):
    plt.plot(rv[i],cc[i])
    #print("Cross-correlation function is maximized at RV = ", rv[i][maxind[i]], " km/s")
    plt.xlabel("Radial velocity in km/s", fontsize=14)
    plt.ylabel("Cross-correlation coefficient", fontsize=14)
    #plt.xlim(-50,50)
    
#     if rv[i][maxind[i]] > 0.0:
#         print("red-shift with respect to the template")
#     else:
#         print("blue-shift with respect to the template")
plt.show()

# %% [markdown]
# Note: The cross correlation works. A systematic error by a factor of 2 is present for all doppler shift km/s. Do not know why this is.

# %% [markdown]
# ---

# %%
cc_test
# Out:
# array([-0.01837164, -0.01919125, -0.02055266, ..., -0.02383945,
#        -0.02365014, -0.02336417])

# %%
cc_test = []
for j in range(2000):
    for i in range(40):
        cc_test.append(cc[i][j])
split = [cc_test[x:x+40] for x in range(0,len(cc_test),40)]

totals = []
for i in range(len(split)):
    sums = sum(split[i])
    sums = sums/40
    totals.append(sums)

# %%
plt.figure(figsize=(20,15))
plt.plot(rv_test,totals)
plt.xlabel("Radial velocity in km/s",fontsize=14)
plt.ylabel("Cross-correlation coefficient",fontsize=14)
plt.show()
#Gaia DR3 illustration

# %% [markdown]
# ### Filtering to obtain averaged CCF

# %% [markdown]
# Reversing the signs of the velocity to get the opposite:

# %%
def reverse_signs(lst): 
    return [ -i for i in lst ]
radvel_gaia_rev = reverse_signs(Gaia_transit)

# %%
# %%time
back_shift_rv = []
for i in range(40):
    back_shift_rv.append(rv[i]+(radvel_gaia_rev[i]*2))
# Out:
# CPU times: user 24.1 ms, sys: 3.09 ms, total: 27.2 ms
# Wall time: 24.6 ms

# %%
# %%time
plt.figure(figsize=(20,15))
for i in range(40):
    plt.plot(back_shift_rv[i],cc[i])
    plt.title('CCfs with RV shifted to rest (RV=0) according to the binary model', fontsize=14)
    plt.xlabel("Radial velocity in km/s", fontsize=14)
    plt.ylabel("Cross-correlation coefficient", fontsize=14)
# Out:
# CPU times: user 42.1 ms, sys: 2.39 ms, total: 44.5 ms
# Wall time: 42.6 ms

# %% [markdown]
# the reverse doppler shift is the "shortcut" instead of brute force.

# %%
tot_rv = np.arange(-1000,1001,1)

# %% [markdown]
# Resampling is used to put all the RV's on the same plot/axis and "space." therefore at each RV bin we can average each CCF.

# %%
# %%time
cc_interp = []

plt.figure(figsize=(20,15))
for i in range(40):
    cc_interp.append(np.interp(tot_rv,back_shift_rv[i],cc[i]))
    plt.plot(tot_rv,cc_interp[i],'s')
    plt.title('RV shifted to rest (RV=0) according to binary model', fontsize=14)
    plt.xlabel("Radial velocity in km/s",fontsize=14)
    plt.ylabel("Cross-correlation coefficient",fontsize=14)
# Out:
# CPU times: user 46.3 ms, sys: 2.57 ms, total: 48.9 ms
# Wall time: 47.5 ms

# %% [markdown]
# ---

# %%
# %%time
cc_interp_test = [cc_interp[i][j] for j in range(2000) for i in range(40)]
split_interp = [cc_interp_test[x:x+40] for x in range(0,len(cc_interp_test),40)]
# Out:
# CPU times: user 57.6 ms, sys: 1.41 ms, total: 59 ms
# Wall time: 58.6 ms

# %%
# %%time
sums_new = [sum(split_interp[i]) for i in range(len(split_interp))]
totals_interp = [sums_new[i]/40 for i in range(len(split_interp))]
# Out:
# CPU times: user 4.51 ms, sys: 27 µs, total: 4.54 ms
# Wall time: 4.55 ms

# %%
tot_rv_less = np.arange(-1000,1000,1)
plt.figure(figsize=(20,15))
plt.plot(tot_rv_less,totals_interp)
plt.show()

# %% [markdown]
# good result.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Nested Sampling

# %%
from numpy import pi, log, sqrt
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior
# Out:
# WARNING: Could not preload libmpi.so.If you are running with MPI, this may cause segfaults

# %% [markdown]
# Sampling method - Position:

# %%
# %time
nDims = 4
nDerived = 0
sigma = 0.1
def likelihood(theta):
    gamma = theta[0]
    K = theta[1]
    P = theta[2]
    tau = theta[3]
    
    """ Obtaining RV values """
    
    RV_sample = []
    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV_sample.append(gamma + K*np.cos(v))
        
    """ Reversing RV values for original 40 values that were just obtained """
    radvel_gaia_rev_sample = [-x for x in RV_sample]
    
    """ Shifting back the original CCF's from earlier by the RV values obtained in the previous step """
    back_shift_rv2 = []
    for i in range(40):
        curve = np.asarray(rv[i]+(radvel_gaia_rev_sample[i]*2))
        back_shift_rv2.append(curve[cc[i]==max(cc[i])])
    back_shift_rv2 = np.asarray(back_shift_rv2) # done because **2 does not work for lists, so switched to np.array

    
    return -sum(back_shift_rv2**2)[0], []
# good for bright stars, not so good for faint as you would evidently shift noise as well as fainter stars
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs

# %%
def prior(hypercube):
    prior = []
    prior.append(UniformPrior(-10, 10)(hypercube[0])) # Gaia search region
    prior.append(UniformPrior(0, 600)(hypercube[1])) # Semi amplituder range from SB9
    prior.append(UniformPrior(0, 1000)(hypercube[2])) # Period range from SB9
    prior.append(UniformPrior(0, 1825)(hypercube[3])) # 5 year nominal mission in days
    return prior

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
settings = PolyChordSettings(nDims, nDerived)
settings.file_root = 'gaussian'
settings.nlive = 50
settings.do_clustering = True
settings.read_resume = False

# %%
# %time
output = pypolychord.run_polychord(likelihood, nDims, nDerived, settings, prior, dumper)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs
# Last dead point: [ 1.65798363e+00  2.08070887e+02  4.82307791e+02  1.49164981e+03
#  -1.92919941e+07 -3.55296848e+06]
# Last dead point: [-8.70577976e+00  7.43050873e+01  2.71649554e+02  1.62741979e+03
#  -1.52222818e+06 -4.71682577e+05]
# Last dead point: [ 2.43581405e+00  2.45926978e+01  2.29491761e+01  1.21499663e+03
#  -4.71682577e+05 -9.37738023e+04]
# Last dead point: [-1.23578578e-01  1.56780043e+01  9.39612114e+02  1.78556191e+03
#  -8.93363278e+04 -4.66673382e+04]
# Last dead point: [ 4.60152222e+00  9.09003521e+00  8.14950126e+02  9.80406545e+02
#  -3.88957093e+04 -3.72813017e+04]
# Last dead point: [-1.21670134e+00  3.17348197e-01  9.33375742e+02  2.75658074e+02
#  -3.53927453e+04 -3.44695482e+04]
# Last dead point: [ 1.59743874e+00  1.83464904e+00  6.48518653e+02  2.93496248e+02
#  -3.34660527e+04 -3.32680414e+04]
# Last dead point: [ 1.33092252e+00  5.80213854e+00  1.51277061e+01  1.30440527e+03
#  -3.34380765e+04 -3.23071759e+04]
# Last dead point: [-7.21238727e-01  5.07431264e+00  7.69989024e+02  9.14314229e+02
#  -3.18223885e+04 -3.15867951e+04]
# Last dead point: [ 1.28179307e+00  6.06882789e+00  4.37191395e+02  1.74990712e+02
#  -3.21070758e+04 -3.08038657e+04]
# Last dead point: [-1.03962820e+00  7.09130194e+00  1.21144649e+02  7.83199840e+02
#  -3.09782488e+04 -2.95519037e+04]
# Last dead point: [ 2.62147156e+00  6.92272796e+00  1.21697789e+02  1.02926772e+03
#  -2.96387851e+04 -2.76943139e+04]
# Last dead point: [-6.55320578e-01  5.40974445e+00  3.99847600e+01  1.72182365e+03
#  -3.00705135e+04 -1.90131013e+04]
# Last dead point: [-2.23452691e+00  7.56706432e+00  3.99299531e+01  1.19804779e+03
#  -1.55729937e+04 -1.53341852e+04]
# Last dead point: [-1.47600408e+00  8.68187332e+00  3.99110258e+01  1.79729689e+03
#  -1.41242091e+04 -1.20519182e+04]
# Last dead point: [ 2.19647381e+00  1.27944796e+01  3.97844344e+01  4.01225972e+02
#  -1.27655542e+04 -9.14829196e+03]
# Last dead point: [-1.84483835e+00  1.40710590e+01  4.01230684e+01  3.16829410e+02
#  -7.82217133e+03 -6.31652526e+03]
# Last dead point: [ 1.83401411e+00  1.42424080e+01  3.98928616e+01  4.42222169e+02
#  -5.64055907e+03 -4.57082968e+03]
# Last dead point: [-1.15464538e+00  1.65996191e+01  4.01291884e+01  9.19370453e+02
#  -3.94573202e+03 -3.39565452e+03]
# Last dead point: [-1.39144629e+00  1.94773371e+01  3.98783104e+01  4.41679286e+02
#  -2.71519913e+03 -2.06152046e+03]
# Last dead point: [-2.64889743e-02  1.96018513e+01  3.99944510e+01  1.98824615e+02
#  -1.54221588e+03 -1.21682025e+03]
# Last dead point: [ 6.98991318e-01  1.73905259e+01  3.99849674e+01  5.20178232e+02
#  -1.10861468e+03 -6.49439949e+02]
# Last dead point: [-9.53164491e-01  2.02295775e+01  3.99886948e+01  8.09111935e+01
#  -1.01566511e+03 -4.13963774e+02]
# Last dead point: [-8.51989551e-01  1.94840730e+01  3.99817584e+01  8.56244841e-01
#  -2.42231252e+03 -2.68153555e+02]
# Last dead point: [ 8.17696568e-01  2.05944052e+01  4.00173851e+01  8.39812467e+02
#  -2.36130295e+02 -1.97611332e+02]
# Last dead point: [-8.03481389e-01  1.93016412e+01  3.99914790e+01  1.60258493e+02
#  -2.00232292e+03 -1.54036492e+02]
# Last dead point: [-1.66712076e-01  1.93085901e+01  3.99881713e+01  2.79944074e+02
#  -1.44605231e+02 -1.10273754e+02]
# Last dead point: [  -0.26752262   19.55794557   39.98558678    0.16426154 -138.51810608
#   -78.36407112]
# Last dead point: [ -0.22022267  19.38866618  40.00340077 159.84932079 -61.80013022
#  -56.03738068]
# Last dead point: [ -0.31631308  19.71309848  39.98609166   0.30986365 -67.86648435
#  -46.87245764]
# Last dead point: [ -0.42945148  20.01954951  39.99606481   0.16769699 -44.83381557
#  -32.24196456]
# Last dead point: [ 3.83801003e-02  2.02210182e+01  4.00021406e+01  2.79842025e+02
#  -4.10769484e+01 -2.11147939e+01]
# Last dead point: [-9.76895686e-02  1.97061493e+01  3.99965113e+01  2.40104548e+02
#  -2.08287737e+01 -1.44616600e+01]
# Last dead point: [-2.23988803e-02  2.00891702e+01  3.99997227e+01  1.01715311e-01
#  -2.95544774e+01 -1.10968687e+01]
# Last dead point: [  0.11393185  19.90343113  39.99703912   0.06440013 -10.68176225
#   -8.06497768]
# Last dead point: [-1.34588210e-01  1.99408619e+01  3.99987536e+01  2.80030827e+02
#  -1.36677590e+01 -6.64203244e+00]
# Last dead point: [ 4.52397455e-02  2.00324127e+01  4.00004215e+01  2.39969558e+02
#  -6.12071234e+00 -5.54688096e+00]
# Last dead point: [-1.29111116e-02  1.99789705e+01  3.99989900e+01  2.39993655e+02
#  -8.06991404e+00 -4.80324473e+00]
# Last dead point: [ 2.03920684e-02  1.99960150e+01  3.99983744e+01  3.79697902e-02
#  -5.58520337e+00 -4.53982354e+00]
# Last dead point: [-4.00466428e-02  2.00287449e+01  3.99986680e+01  2.80033368e+02
#  -4.44799127e+00 -4.37332423e+00]
# Last dead point: [-4.28071934e-02  2.00039466e+01  3.99988736e+01  2.40025035e+02
#  -4.33561866e+00 -4.29295519e+00]
# Last dead point: [-2.21128106e-02  2.00051883e+01  3.99987473e+01  2.60091289e-02
#  -4.30637997e+00 -4.26036791e+00]
# Last dead point: [-1.61882082e-02  2.00176193e+01  3.99990806e+01  2.08691761e-02
#  -4.32062654e+00 -4.23981272e+00]
# Last dead point: [-2.25391808e-02  2.00105017e+01  3.99990832e+01  2.80017733e+02
#  -4.23160174e+00 -4.21714229e+00]

# %%
#paramnames = [('p%i' % i, r'\theta_%i' % i) for i in range(nDims)]
paramnames = [('cc_coeff', 'gamma'),('cc_coeff', 'K'),('cc_coeff','p'), ('cc_coeff', 'tau')]
output.make_paramnames_files(paramnames)
paramnames
# Out:
# [('cc_coeff', 'gamma'),
#  ('cc_coeff', 'K'),
#  ('cc_coeff', 'p'),
#  ('cc_coeff', 'tau')]

# %%
try:
    from anesthetic import NestedSamples
    samples = NestedSamples(root= settings.base_dir + '/' + settings.file_root)
    fig, axes = samples.plot_2d(paramnames)
    fig.savefig('posterior position.pdf')

except ImportError:
    try:
        import getdist.plots
        posterior = output.posterior
        g = getdist.plots.getSubplotPlotter()
        g.triangle_plot(posterior, filled=True)
        g.export('posterior.pdf')
    except ImportError:
        print("Install matplotlib and getdist for plotting examples")

    print("Install anesthetic or getdist  for for plotting examples")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#       1 try:
#       2     from anesthetic import NestedSamples
# ----> 3     samples = NestedSamples(root= settings.base_dir + '/' + settings.file_root)
#       4     fig, axes = samples.plot_2d(paramnames)
#       5     fig.savefig('posterior position.pdf')
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/anesthetic/samples.py in __init__(self, *args, **kwargs)
#     442             limits = reader.limits()
#     443             kwargs['label'] = kwargs.get('label', os.path.basename(root))
# --> 444             self.__init__(data=samples, columns=columns,
#     445                           logL=logL, logL_birth=logL_birth,
#     446                           tex=tex, limits=limits, *args, **kwargs)
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/anesthetic/samples.py in __init__(self, *args, **kwargs)
#     454                                       logL_birth)
#     455
# --> 456             super(NestedSamples, self).__init__(logzero=logzero,
#     457                                                 *args, **kwargs)
#     458             if logL_birth is not None:
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/anesthetic/samples.py in __init__(self, *args, **kwargs)
#     105                 self.tex['weight'] = r'MCMC weight'
#     106
# --> 107             self._set_automatic_limits()
#     108
#     109     def _set_automatic_limits(self):
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/anesthetic/samples.py in _set_automatic_limits(self)
#     111         for param in self.columns:
#     112             if param not in self.limits:
# --> 113                 self.limits[param] = (self[param].min(), self[param].max())
#     114
#     115     def plot(self, ax, paramname_x, paramname_y=None, *args, **kwargs):
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2810             indexer = np.where(indexer)[0]
#    2811
# -> 2812         data = self._take_with_is_copy(indexer, axis=1)
#    2813
#    2814         if is_single_key:
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
# -> 3397         return self._constructor(new_data).__finalize__(self)
#    3398
#    3399     def _take_with_is_copy(
#
# ... last 6 frames repeated, from the frame below ...
#
# ~/.pyenv/versions/3.8.2/envs/gaia/lib/python3.8/site-packages/anesthetic/samples.py in __init__(self, *args, **kwargs)
#     454                                       logL_birth)
#     455
# --> 456             super(NestedSamples, self).__init__(logzero=logzero,
#     457                                                 *args, **kwargs)
#     458             if logL_birth is not None:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
gaussian = pd.read_fwf('/users/azib/documents/msc_thesis/chains/gaussian.txt')

# %%
gaussian.columns = ['weights','likelihood','gamma','K','P','tau']

# %%
gaussian

# %%
max_l = gaussian.loc[gaussian['likelihood'].idxmax()]
max_l

# %% [markdown]
# ---

# %% [markdown]
# Sampling method - Height:

# %%
# %%time
nDims = 4
nDerived = 0
sigma = 0.1
def sample(theta):
    gamma = theta[0]
    K = theta[1]
    P = theta[2]
    tau = theta[3]
    
    """ Obtaining RV values """
    
    RV_sample = []
    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV_sample.append(gamma + K*np.cos(v))
        
    """ Reversing RV values for original 40 values that were just obtained """
    radvel_gaia_rev_sample = [-x for x in RV_sample]
    
    """ Shifting back the original CCF's from earlier by the RV values obtained in the previous step """
    back_shift_rv2 = [(rv[i]+(radvel_gaia_rev_sample[i]*2)) for i in range(40)]
    
    back_shift_rv2 = []
    for i in range(40):
        curve = np.asarray(rv[i]+(radvel_gaia_rev_sample[i]*2))
        back_shift_rv2.append(curve[cc[i]==max(cc[i])])
    back_shift_rv2 = np.asarray(back_shift_rv2)

    """ resmapling onto a new template from -1000 to 1000 in steps of 1km/s """
    tot_rv = np.arange(-1000,1000,1)
    cc_interp = [np.interp(tot_rv,back_shift_rv2[i],cc[i]) for i in range(40)]

    """ splitting the sample into batches of 40 to be able to perform the next step """

    cc_interp_test = [cc_interp[i][j] for j in range(2000) for i in range(40)]
    split_interp = [cc_interp_test[x:x+40] for x in range(0,len(cc_interp_test),40)]
            
    """ taking each index of the 40 values and performing averaging calculations """
        
    sums_new = [sum(split_interp[i]) for i in range(len(split_interp))]
    totals_interp = [sums_new[i]/40 for i in range(len(split_interp))]
    totals_interp_asarray = np.asarray(totals_interp)
    
  
    return max(totals_interp_asarray)**2, []
# Out:
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 12.2 µs

# %%
def prior(hypercube):
    prior = []
    prior.append(UniformPrior(-1000, 1000)(hypercube[0])) # Gaia search region
    prior.append(UniformPrior(0, 600)(hypercube[1])) # Semi amplituder range from SB9
    prior.append(UniformPrior(0, 1000)(hypercube[2])) # Period range from SB9
    prior.append(UniformPrior(0, 1825)(hypercube[3])) # 5 year nominal mission in days
    return prior

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
settings_height = PolyChordSettings(nDims, nDerived)
settings_height.file_root = 'gaussian height'
settings_height.nlive = 30
settings_height.do_clustering = True
settings_height.read_resume = False

# %%
# %time
output = pypolychord.run_polychord(sample, nDims, nDerived, settings_height, prior, dumper)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 3.81 µs
# Last dead point: [-1.45171773e+02  4.42764366e+02  5.19022308e+02  1.11947844e+03
#   6.98250915e-03  2.90080398e-02]
# Last dead point: [-2.75807393e+02  1.94794443e+02  8.01316760e+02  6.46312023e+02
#   4.32738868e-02  6.72049613e-02]
# Last dead point: [1.90577988e+02 7.23788763e+01 3.02466989e+02 7.54435865e+02
#  3.82138428e-02 2.40307730e-01]
# Last dead point: [1.81448662e+02 3.62887410e+01 1.86900217e+02 1.73096277e+03
#  3.76603508e-01 4.66062201e-01]
# Last dead point: [1.49288399e+02 8.94815486e+00 5.27466090e+02 9.47650259e+02
#  5.96313779e-01 5.96681221e-01]
# Last dead point: [2.02960827e+02 1.42737976e+01 5.85236533e+02 4.48888172e+02
#  4.39411656e-01 6.19213651e-01]
# Last dead point: [1.61181940e+02 1.70164630e+01 7.88969168e+02 1.56216948e+03
#  6.29562838e-01 6.33472207e-01]
# Last dead point: [4.99091007e+02 1.56705092e+01 3.96591945e+01 1.43629618e+03
#  6.31465987e-01 7.74799179e-01]

# %%
paramnames = [('p%i' % i, r'\theta_%i' % i) for i in range(nDims)]
#paramnames = [('cc_coeff', '\\gamma'),('cc_coeff', '\\K'),('cc_coeff','\\p'), ('cc_coeff', '\\tau')]
output.make_paramnames_files(paramnames)

# %%
try:
    from anesthetic import NestedSamples
    samples = NestedSamples(root= settings_height.base_dir + '/' + settings_height.file_root)
    fig, axes = samples.plot_2d(['p0','p1','p2','p3'])
    fig.savefig('posterior height.pdf')

except ImportError:
    try:
        import getdist.plots
        posterior = output.posterior
        g = getdist.plots.getSubplotPlotter()
        g.triangle_plot(posterior, filled=True)
        g.export('posterior.pdf')
    except ImportError:
        print("Install matplotlib and getdist for plotting examples")

    print("Install anesthetic or getdist  for for plotting examples")

# %%
gaussian_height = pd.read_fwf('/users/azib/documents/msc_thesis/chains/gaussian height.txt')

# %%
gaussian_height.columns = ['weights','likelihood','gamma','K','P','tau']

# %%
max_l_height = gaussian_height.loc[gaussian_height['likelihood'].idxmax()]
max_l_height
